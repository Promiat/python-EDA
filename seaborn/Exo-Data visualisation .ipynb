# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
house_pricing = pd.read_csv('./DATA/house_pricing.csv')

# %%
house_pricing.head(15)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1          60       RL         65.0     8450   Pave   NaN      Reg
# 1    2          20       RL         80.0     9600   Pave   NaN      Reg
# 2    3          60       RL         68.0    11250   Pave   NaN      IR1
# 3    4          70       RL         60.0     9550   Pave   NaN      IR1
# 4    5          60       RL         84.0    14260   Pave   NaN      IR1
# 5    6          50       RL         85.0    14115   Pave   NaN      IR1
# 6    7          20       RL         75.0    10084   Pave   NaN      Reg
# 7    8          60       RL          NaN    10382   Pave   NaN      IR1
# 8    9          50       RM         51.0     6120   Pave   NaN      Reg
# 9   10         190       RL         50.0     7420   Pave   NaN      Reg
# 10  11          20       RL         70.0    11200   Pave   NaN      Reg
# 11  12          60       RL         85.0    11924   Pave   NaN      IR1
# ...

# %%
house_pricing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
sns.scatterplot(data=house_pricing,x="LotArea",y="SalePrice")
# Out:
# <AxesSubplot:xlabel='LotArea', ylabel='SalePrice'>

# %%
filter_tab = house_pricing[(house_pricing['LotArea'] <= 20000) & (house_pricing['SalePrice'] <= 500000)]
sns.scatterplot(data=filter_tab,x="LotArea",y="SalePrice")
# Out:
# <AxesSubplot:xlabel='LotArea', ylabel='SalePrice'>

# %%
test = sns.scatterplot(data=filter_tab,x="LotArea",y="LotFrontage",hue='LotFrontage')

# %%
filter_tab_2 = house_pricing[(house_pricing['LotArea'] <= 100000) &(house_pricing['LotFrontage'] <= 200)]
sns.scatterplot(data=filter_tab,x="LotArea",y="LotFrontage")
# Out:
# <AxesSubplot:xlabel='LotArea', ylabel='LotFrontage'>

# %%
sales_prediction = pd.read_csv('./DATA/sales_predictions.csv')
sales_prediction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2935849 entries, 0 to 2935848
# Data columns (total 6 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   date            object
#  1   date_block_num  int64
#  2   shop_id         int64
#  3   item_id         int64
#  4   item_price      float64
#  5   item_cnt_day    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 134.4+ MB

# %%
global_tab = sns.relplot(data=sales_prediction, y='item_price',x='date')
global_tab
# Out:
# Error in callback <function flush_figures at 0x000001EF41FFE430> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\users\mathias\python\python38\lib\site-packages\ipykernel\pylab\backend_inline.py in flush_figures()
#     117         # ignore the tracking, just draw and close all figures
#     118         try:
# --> 119             return show(True)
#     120         except Exception as e:
#     121             # safely show traceback if in IPython, else raise
#
# c:\users\mathias\python\python38\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      37     try:
#      38         for figure_manager in Gcf.get_all_fig_managers():
# ---> 39             display(
#      40                 figure_manager.canvas.figure,
#      41                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ...

# %%
new_sales_predictions = sales_prediction.sample(n=50, random_state=1)
sns.relplot(data = new_sales_predictions, x= "date", y= "item_price")

# %%
new_sales_predictions = sales_prediction.sample(n=100, random_state=1)
sns.relplot(data = new_sales_predictions, x= "date", y= "item_price")

# %%
pd.to_datetime(new_sales_predictions['date'])
# Out:
# 651498    2013-12-07
# 460637    2013-05-18
# 1696749   2014-05-18
# 1081839   2013-04-11
# 1865398   2014-04-07
#              ...
# 1884269   2014-09-08
# 2113515   2014-11-11
# 203150    2013-05-02
# 2515149   2015-03-22
# 1376412   2014-02-25
# Name: date, Length: 100, dtype: datetime64[ns]

# %%
sns.relplot(data = new_sales_predictions, x= pd.to_datetime(new_sales_predictions['date']), y= "item_price")

# %% [raw]
# Exo 3

# %%
ibm_hr_attrition = pd.read_csv('./DATA/ibm_hr_attrition.csv')
ibm_hr_attrition.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
filter_tab_ibm = sns.catplot(data=ibm_hr_attrition, x='Attrition', y='JobSatisfaction',kind="bar")

# %%
ibm_hr_attrition['JobSatisfaction'].describe()
# Out:
# count    1470.000000
# mean        2.728571
# std         1.102846
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         4.000000
# Name: JobSatisfaction, dtype: float64

# %%
sns.boxplot(data=ibm_hr_attrition, x='Attrition', y='JobSatisfaction')
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='JobSatisfaction'>

# %% [raw]
# Pas de valeurs abérentes car pas de "points" (voire wikipédia)

# %%
ibm_hr_attrition.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
satisfaction_tab = ibm_hr_attrition[(ibm_hr_attrition['JobSatisfaction']<= 3) & (ibm_hr_attrition['Attrition'] == 'No' )]
satisfaction_tab
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1      49        No  Travel_Frequently        279  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# 6      59        No      Travel_Rarely       1324  Research & Development
# 7      30        No      Travel_Rarely       1358  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1464   26        No      Travel_Rarely       1167                   Sales
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
ibm_hr_attrition.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
satisfaction_tab.describe()
# Out:
#               Age    DailyRate  DistanceFromHome   Education  EmployeeCount  \
# count  826.000000   826.000000        826.000000  826.000000          826.0
# mean    37.760291   814.303874          8.920097    2.927361            1.0
# std      8.918659   408.413378          7.913833    1.021966            0.0
# min     18.000000   106.000000          1.000000    1.000000            1.0
# 25%     31.000000   470.250000          2.000000    2.000000            1.0
# 50%     36.000000   818.500000          7.000000    3.000000            1.0
# 75%     44.000000  1183.250000         13.000000    4.000000            1.0
# max     60.000000  1499.000000         29.000000    5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count      826.000000               826.000000  826.000000       826.00000
# mean      1048.048426                 2.768765   66.504843         2.77845
# ...

# %% [raw]
# On peux voire que les variable abérante sont enfaite les salarié quio ont bcp d'ancienneté (plus que la moyenne générale) on  vois aussi qu'ils ont en générale moins de promotions

# %%
filter_tab_ibm = sns.catplot(data=ibm_hr_attrition, x='Attrition', y='JobSatisfaction',kind="bar")

# %%
filter_tab_ibm2 = sns.catplot(data=ibm_hr_attrition, x='Attrition', y='TotalWorkingYears', kind='bar')

# %%
sns.catplot(data=ibm_hr_attrition, x='Attrition', y='TotalWorkingYears',kind='box')

# %%
working_years_tab = ibm_hr_attrition[(ibm_hr_attrition['TotalWorkingYears']<= 10) & (ibm_hr_attrition['Attrition'] == 'Yes' )]
working_years_tab
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 14     28       Yes      Travel_Rarely        103  Research & Development
# 21     36       Yes      Travel_Rarely       1218                   Sales
# 24     34       Yes      Travel_Rarely        699  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1379   27       Yes  Travel_Frequently       1337         Human Resources
# 1390   28       Yes      Travel_Rarely       1404  Research & Development
# 1395   31       Yes  Travel_Frequently        754                   Sales
# 1438   23       Yes  Travel_Frequently        638                   Sales
# 1442   29       Yes      Travel_Rarely       1092  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
ibm_hr_attrition.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
working_years_tab.describe()
# Out:
#               Age    DailyRate  DistanceFromHome   Education  EmployeeCount  \
# count  182.000000   182.000000        182.000000  182.000000          182.0
# mean    30.840659   749.450549         10.554945    2.785714            1.0
# std      8.199306   403.395608          8.361630    0.987890            0.0
# min     18.000000   103.000000          1.000000    1.000000            1.0
# 25%     26.000000   385.000000          3.000000    2.000000            1.0
# 50%     30.000000   696.000000          9.000000    3.000000            1.0
# 75%     34.000000  1088.000000         17.000000    3.000000            1.0
# max     58.000000  1496.000000         29.000000    5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count      182.000000               182.000000  182.000000      182.000000
# mean       990.637363                 2.489011   65.945055        2.521978
# ...

# %% [raw]
# Les employés les moins satisfait sont en générale plus jeunes, on un job level moins élevés, on mùoins de stockoption. ils sont donc moins impliqué dans la réussite de l'entreprise. On constate aussi qu'ils passent moins de temps sur le même poste.

# %%
ibm_hr_attrition['EducationField']
# Out:
# 0       Life Sciences
# 1       Life Sciences
# 2               Other
# 3       Life Sciences
# 4             Medical
#             ...
# 1465          Medical
# 1466          Medical
# 1467    Life Sciences
# 1468          Medical
# 1469          Medical
# Name: EducationField, Length: 1470, dtype: object

# %%
ibm_hr_attrition['EducationField'].describe()
# Out:
# count              1470
# unique                6
# top       Life Sciences
# freq                606
# Name: EducationField, dtype: object

# %%
#ibm_hr_attrition['Attrition'] = ibm_hr_attrition['Attrition'].apply(lambda x: 0 if x == 'No' else 1)
#ibm_hr_attrition_test = ibm_hr_attrition[(ibm_hr_attrition['Attrition'] == 0)]
#ibm_hr_attrition_test
ibm_hr_attrition = pd.read_csv('./DATA/ibm_hr_attrition.csv')
ibm_hr_attrition['Attrition'] = ibm_hr_attrition['Attrition'].apply(lambda x: 0 if x == 'No' else 1)

# %%
test1 = sns.catplot(data=ibm_hr_attrition, y='EducationField',kind='count', col='Attrition')
test2 = sns.catplot(data=ibm_hr_attrition, x='EducationField', y='Attrition', kind='bar', height=10)
test2

# %%
sns.displot(data=ibm_hr_attrition, x='Attrition', y='EducationField', kind='hist')

# %% [raw]
# Exo 4

# %%
sns.displot(data=ibm_hr_attrition, x='MonthlyIncome', kind='hist')

# %%
range_salaray = ibm_hr_attrition[(ibm_hr_attrition['TotalWorkingYears']<= 10)
